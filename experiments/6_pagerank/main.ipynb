# %%
import os
ROOT = os.path.join('..', '..')
import sys
sys.path.append(ROOT)
# 
from tqdm import tqdm
import numpy as np
import pandas as pd
import polars as pl
import altair as alt
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
class PageRankRecommender():
    def __init__(self, ml_movies_df, ml_users_df):
        self.ml_movies_df = ml_movies_df
        self.ml_users_df = ml_users_df
        self.A_norm = None
        if os.path.exists("A_norm.npy"):
            self.A_norm = np.load("A_norm.npy")
    
    def fit(self, ml_ratings_train_df):
        if self.A_norm is None:
            print("Initializing adjacency matrix...")
            self._init_adjacency_matrix(ml_ratings_train_df)
            np.save("A_norm.npy", self.A_norm)
        self.pagerank_scores = self._pagerank(self.A_norm)
        self.ml_ratings_train_df = ml_ratings_train_df
    
    def predict(self, user_id, n_recommendations):
        movies_ids = self.ml_movies_df['MovieID'].values
        user_rated_movies_idx = self.ml_ratings_train_df[self.ml_ratings_train_df["UserID"] == user_id]["MovieID"].values
        scores = pd.DataFrame(self.pagerank_scores, index=movies_ids, columns=["Score"])\
            .sort_values("Score", ascending=False)\
            .drop(user_rated_movies_idx, errors='ignore').head(n_recommendations)
        return scores
    
    def evaluate(ml_ratings_test_df, k):
        pass
    
    def _init_adjacency_matrix(self, ml_ratings_train_df):
        movies_ids = self.ml_movies_df['MovieID'].values
        A_df = pd.DataFrame(0, index=movies_ids, columns=movies_ids)
        user_groups = ml_ratings_train_df.sort_values("Rating", ascending=False).groupby("UserID")
        for _, user_group in tqdm(user_groups):
            ratings = user_group["Rating"].values
            movie_ids = user_group["MovieID"].values
            diff_matrix = -np.subtract.outer(ratings, ratings)
            diff_matrix = np.maximum(diff_matrix, 0)
            A_df.loc[movie_ids, movie_ids] += diff_matrix
        A = A_df.values
        row_sums = A.sum(axis=1, keepdims=True)
        row_sums[row_sums == 0] = 1  # Handle rows with all zeros
        A_norm = A / row_sums
        self.A_norm = A_norm
        
    def _pagerank(self, A, d=0.85, eps=1e-8, max_iter=100):
        N = A.shape[0]
        p = np.ones(N) / N
        for _ in tqdm(range(max_iter)):
            p_new = (1 - d) / N + d * A.T.dot(p)
            if np.linalg.norm(p_new - p) < eps:
                break
            p = p_new
        return p

# %%
from scripts.data import (
    ml_ratings_df, ml_movies_df, ml_users_df, ml_df, ml_genres,
    bc_ratings_df, bc_books_df, bc_users_df, bc_df,
)
from src.metrics import (
    ml_precision_at_k, ml_recall_at_k, ml_f1_at_k,
    ml_precision_at_k_pl, ml_recall_at_k_pl, ml_f1_at_k_pl
)

# %%
idx = pl.Series(range(ml_ratings_df.select(pl.len()).collect().item()))
idx = idx.shuffle(seed=42)
train_size = int(len(idx) * 0.8)
train_idx = idx[:train_size]
test_idx = idx[train_size:]

ml_ratings_train_df = ml_ratings_df.collect()[train_idx, :]
ml_ratings_test_df = ml_ratings_df.collect()[test_idx, :]
ml_ratings_train_df.select(pl.len()).item(), ml_ratings_test_df.select(pl.len()).item()
# Out:
# (800167, 200042)

# %%
ml_movies_df = ml_movies_df.collect().to_pandas()
ml_ratings_train_df = ml_ratings_train_df.to_pandas()
ml_ratings_test_df = ml_ratings_test_df.to_pandas()
ml_users_df = ml_users_df.collect().to_pandas()

# %%
recommender = PageRankRecommender(ml_movies_df, ml_users_df)
recommender.fit(ml_ratings_train_df)
# Out:
#  22%|██▏       | 22/100 [00:00<00:01, 77.60it/s]

# %%
recommendations = recommender.predict(1, 100)
recommendations = recommendations.reset_index()
recommendations.columns = ["MovieID", "Score"]
recommendations
# Out:
#     MovieID     Score
# 0       259  0.003388
# 1       857  0.003024
# 2       607  0.002841
# 3       526  0.002793
# 4       295  0.002678
# ..      ...       ...
# 95     1673  0.001145
# 96     2691  0.001141
# 97     1672  0.001136
# 98     2699  0.001135
# 99     1640  0.001128
#
# [100 rows x 2 columns]

# %%
best_metric = -1
best_user_id = 0
for user_id in ml_ratings_test_df["UserID"].unique():
    metric = ml_precision_at_k(5, recommendations, ml_ratings_test_df, user_id, True)
    if metric > best_metric:
        best_metric = metric
        best_user_id = user_id
        print(f"User {user_id}: {metric}")
# Out:
# User 2104: 0.4
# User 5746: 0.6
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4675!
# User 1723: 0.8
# Warning: len(ml_user_ratings_test_df) < k for user with ID 591!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3420!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1411!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2183!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 510!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4018!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3406!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4412!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4985!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1509!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 583!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3747!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4002!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4596!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5578!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1581!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 985!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 544!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2530!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2583!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2774!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 482!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3371!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 196!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4395!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3243!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2815!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 63!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 897!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1434!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5273!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3797!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4190!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1438!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5799!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2127!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2652!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4798!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2027!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5718!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2754!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2036!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1655!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1069!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1383!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 534!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4009!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1268!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 824!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 382!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1519!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2955!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2481!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2670!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3263!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1549!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 825!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2383!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1478!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5279!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4702!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2192!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2922!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5803!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5820!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2374!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5528!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1535!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1173!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4144!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2251!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1762!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2346!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2116!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1370!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2706!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 834!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3395!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1710!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4399!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5470!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2970!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4274!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4870!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1609!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5590!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2501!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2553!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 276!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4676!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 531!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5694!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3272!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1671!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2233!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3796!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2267!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2672!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1507!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3932!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1829!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 88!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1248!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5983!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4258!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2064!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1538!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1891!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4491!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 760!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2548!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 70!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5693!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3211!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1632!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3827!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2380!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5897!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4991!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1843!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4007!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4462!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4213!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2132!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2796!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5466!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5532!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4718!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 163!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4748!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3721!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4324!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1179!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4494!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 416!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2513!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1794!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1897!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 454!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 314!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2515!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3910!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4196!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5383!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4754!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 599!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3290!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3914!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1470!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2259!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4786!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2686!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4852!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1928!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1848!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4925!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3882!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5724!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 380!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4175!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 774!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3324!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5149!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2713!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2291!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1663!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3551!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2412!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2728!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 4390!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 931!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2494!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2638!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2181!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3387!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 971!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5605!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3494!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5809!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5524!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 5795!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 316!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1487!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1810!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1281!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1717!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 3931!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 526!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1430!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 1187!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 2313!
# Warning: len(ml_user_ratings_test_df) < k for user with ID 